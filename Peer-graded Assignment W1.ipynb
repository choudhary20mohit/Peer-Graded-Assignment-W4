# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Mohit Choudhary</b>

# %% [markdown]
# *I am interested in data science because I am interested in playing with data. As data science is the current trend in market and we have shortage of data scientist. I am preparing for data science by learning the data science technologies*

# %% [markdown]
# ### My code will print even and odd number from range 0 to 5

# %%
for i in range(5):
    if i%2==0:
        print("Number is Even: " +str(i))
    else:
        print("Number is Odd:  " +str(i))
# Out:
# Number is Even: 0
# Number is Odd:  1
# Number is Even: 2
# Number is Odd:  3
# Number is Even: 4

# %% [markdown]
# - Bulleted list1
# - Bulleted list2
#
# 1. Numbered list1
# 2. Numbered list2
#
# ![penguin-158551__340.webp](attachment:penguin-158551__340.webp)
#
#
# Code syntax highlighting:
# ` for i in range(5):!`
# `    if i%2==0:!`
# `        print("Number is Even: " +str(i))!`
# `    else:!`
# `        print("Number is Odd:  " +str(i))!`
